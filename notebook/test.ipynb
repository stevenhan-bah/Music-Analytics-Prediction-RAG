# %% [markdown]
# Additonal code to convert data

# %%
import pandas as pd

df = pd.read_parquet("RAG_data/music_data_for_analytics.parquet")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3185328 entries, 0 to 3185327
# Data columns (total 32 columns):
#  #   Column                                Dtype
# ---  ------                                -----
#  0   bpm                                   float64
#  1   bpm_histogram_first_peak_bpm_mean     float64
#  2   bpm_histogram_first_peak_bpm_median   float64
#  3   bpm_histogram_second_peak_bpm_mean    float64
#  4   bpm_histogram_second_peak_bpm_median  float64
#  5   danceability                          float64
#  6   onset_rate                            float64
#  7   average_loudness                      float64
#  8   dynamic_complexity                    float64
#  9   mfcc_zero_mean                        float64
#  10  tuning_frequency                      float64
#  11  tuning_equal_tempered_deviation       float64
#  12  key_key                               str
#  13  key_scale                             str
#  14  mood_happy_prob                       float64
#  15  mood_aggressive_prob                  float64
#  16  mood_happy                            str
#  17  mood_sad                              str
#  18  mood_relaxed                          str
#  19  mood_aggressive                       str
#  20  mood_acoustic                         str
#  21  mood_electronic                       str
#  22  mood_party                            str
#  23  voice_gender                          str
#  24  timbre                                str
#  25  tonal_atonal                          str
#  26  voice_instrumental                    str
#  27  release_name                          str
#  28  recording_name                        str
#  29  release_year                          float64
#  30  artist_name                           str
#  31  main_genre                            str
# dtypes: float64(15), str(17)
# memory usage: 1.2 GB

# %%
df['key_scale'] = df['key_scale'].map({'major' : 1, 'minor' : 0})
df['mood_happy'] = df['mood_happy'].map({'happy' : 1, 'not_happy' : 0})
df['mood_sad'] = df['mood_sad'].map({'sad' : 1, 'not_sad' : 0})
df['mood_relaxed'] = df['mood_relaxed'].map({'relaxed' : 1, 'not_relaxed' : 0})
df['mood_aggressive'] = df['mood_aggressive'].map({'aggressive' : 1, 'not_aggressive' : 0})
df['mood_acoustic'] = df['mood_acoustic'].map({'acoustic' : 1, 'not_acoustic' : 0})
df['mood_electronic'] = df['mood_electronic'].map({'electronic' : 1, 'not_electronic' : 0})

df['mood_party'] = df['mood_party'].map({'party' : 1, 'not_party' : 0})

df['voice_gender'] = df['voice_gender'].map({'female' : 1, 'male' : 0})

df['timbre'] = df['timbre'].map({'bright' : 1, 'dark' : 0})

df['tonal_atonal'] = df['tonal_atonal'].map({'tonal' : 1, 'atonal' : 0})

df['voice_instrumental'] = df['voice_instrumental'].map({'voice' : 1, 'instrumental' : 0})

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3185328 entries, 0 to 3185327
# Data columns (total 32 columns):
#  #   Column                                Dtype
# ---  ------                                -----
#  0   bpm                                   float64
#  1   bpm_histogram_first_peak_bpm_mean     float64
#  2   bpm_histogram_first_peak_bpm_median   float64
#  3   bpm_histogram_second_peak_bpm_mean    float64
#  4   bpm_histogram_second_peak_bpm_median  float64
#  5   danceability                          float64
#  6   onset_rate                            float64
#  7   average_loudness                      float64
#  8   dynamic_complexity                    float64
#  9   mfcc_zero_mean                        float64
#  10  tuning_frequency                      float64
#  11  tuning_equal_tempered_deviation       float64
#  12  key_key                               str
#  13  key_scale                             int64
#  14  mood_happy_prob                       float64
#  15  mood_aggressive_prob                  float64
#  16  mood_happy                            int64
#  17  mood_sad                              int64
#  18  mood_relaxed                          int64
#  19  mood_aggressive                       int64
#  20  mood_acoustic                         int64
#  21  mood_electronic                       int64
#  22  mood_party                            int64
#  23  voice_gender                          int64
#  24  timbre                                int64
#  25  tonal_atonal                          int64
#  26  voice_instrumental                    int64
#  27  release_name                          str
#  28  recording_name                        str
#  29  release_year                          float64
#  30  artist_name                           str
#  31  main_genre                            str
# dtypes: float64(15), int64(12), str(5)
# memory usage: 945.5 MB

# %%
# import pandas as pd

# df = pd.read_parquet("RAG_data/music_data_for_analytics.csv")

# df.to_csv("RAG_data/music_data_for_analytics.csv", index=False)

# %%
df.to_parquet("RAG_data/new_music_data_for_analytics.parquet")

# %%
import pandas as pd

df.to_csv('RAG_data/new_music_data_for_analytics.csv')
